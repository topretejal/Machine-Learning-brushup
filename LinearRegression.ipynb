# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
#Creating the dataframe
df=pd.read_csv('Advertising.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#creating binary dataframe
df_binary=df[['TV','sales']]
df_binary.head()
# Out:
#       TV  sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
df_binary.columns=['TV','sales']
df_binary.head()
# Out:
#       TV  sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
#plotting the df
sns.lmplot(x='TV',y='sales', data=df_binary,order=2,ci=None)

# %%
df_binary.fillna(method='ffill',inplace=True)
# Out:
# /home/tejal/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4327: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
#plotting the df
sns.lmplot(x='TV',y='sales', data=df_binary,order=2,ci=None)

# %%
x=np.array(df_binary['TV']).reshape(-1,1)
y=np.array(df_binary['sales']).reshape(-1,1)

# %%
#splitting the dataset
x_train, x_test, y_train, y_test=train_test_split(x,y,test_size=0.25)

# %%
#fitting the model
reg=LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(x_test)
y_pred
# Out:
# array([[18.77652827],
#        [ 8.38700511],
#        [ 7.14845112],
#        [13.91443615],
#        [17.50214833],
#        [15.83368304],
#        [17.91670566],
#        [15.4856596 ],
#        [ 6.98467538],
#        [ 8.05945364],
#        [14.3136395 ],
#        [18.23913914],
#        [14.78961273],
#        [17.76316591],
#        [20.23003791],
#        [17.69663202],
#        [10.59797752],
#        [ 7.69095824],
#        [15.13251817],
#        [19.48792911],
#        [18.15725127],
#        [16.88798933],
#        [19.50840108],
#        [13.5152328 ],
#        [21.11545048],
#        [ 7.65513229],
#        [10.15783024],
#        [15.31164788],
#        [21.14104044],
#        [ 9.05234403],
#        [17.00058515],
#        [18.52062868],
#        [14.4364713 ],
#        [19.61587891],
#        [15.60337341],
#        [13.69436251],
#        [19.02219187],
#        [15.54195751],
#        [20.43475758],
#        [19.76430067],
#        [12.96760768],
# ...

# %%
#visualize
plt.scatter(x_test,y_test,color='b')
plt.plot(x_test,y_pred,color='k')
plt.show()
